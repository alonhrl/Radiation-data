# %%
import os
import csv
import codecs
from datetime import datetime
import pandas as pd
from itertools import zip_longest

pathToProcessedData = '/Users/alonhrl/Documents/Alon/MA-MSC/development/Bar-Ilan data'
rawDataFile = 'Solar_radiation_1h.csv'
pathToRawData = '/Users/alonhrl/Documents/Alon/MA-MSC/development/Radiation-data/Bar-Ilan'
dayRadList = []
monRadList = []
startHour = 24
endHour = 0
earliestHour = 6
latestHour = 19
startTime = datetime.strptime('09-01-2021-05:00', '%m-%d-%Y-%H:%M') # <-- set to correct start time according to first line in file
prevDate = startTime.date()

def handle_month_end():
    global monRadList
    global startHour
    global endHour
    global prevDate
    global currDate
    
    fileName = 'bar_ilan-' + str(prevDate.month).zfill(2) + '-' + str(prevDate.year)[2:] + '.csv'
    print("New month: %02d, saving to file %s, start: %d, end %d" % (currDate.date().month, fileName, startHour, endHour))
    #Create a DataFrame out of the monthly radiation list
    data = [[float(value) for value in inner_list] for inner_list in monRadList]
    #Find the maximum length among the inner lists
    max_length = max(len(inner_list) for inner_list in data)
    #Fill the gaps with zeros
    filled_data = [inner_list + [0] * (max_length - len(inner_list)) for inner_list in data]
    column_names = [str(i) for i in range(earliestHour, latestHour+1)]
    df = pd.DataFrame(filled_data, columns=column_names)
    fullPathFile = os.path.join(pathToProcessedData, fileName)
    df.to_csv(fullPathFile, index=False)
    startHour = 24
    endHour = 0
    monRadList = []
        

def handle_day_end(forDate):
    global dayRadList
    global monRadList
   
    print("New date: %s, #elements %d"%(forDate.strftime("%m/%d/%Y"), len(dayRadList)))
    #add daily radiation to monthly list
    monRadList.append(dayRadList)
    dayRadList = []
    
fullPathRawDataFile = os.path.join(pathToRawData, rawDataFile)
with codecs.open(fullPathRawDataFile, 'r', encoding='utf-8-sig') as csvfile:
    reader = csv.DictReader(csvfile)
   
    for l in reader:
        currDate = datetime.strptime(l['Date'], ' %d/%m/%y %H:%M')
        #Skip this if it is the first line in the file
        if currDate.date().month != prevDate.month and currDate != startTime:
            #first, end day and then end month
            handle_day_end(prevDate)
            handle_month_end()
            prevDate = currDate.date()
        else:
            if currDate.date() != prevDate and currDate != startTime:
                handle_day_end(prevDate)
                prevDate = currDate.date()
        
        #ignore hours earlier than 06:00 and later than 19:00
        if  (int(currDate.hour) < 6) or (int(currDate.hour) > 19):
            continue
        #ignore 'No Data' values
        if l['B_ILAN_212_1'] == 'NoData':
            continue
        #if (float(l['B_ILAN_212_1']) > 0):
        dayRadList.append(l['B_ILAN_212_1'])
        #update the earliest hour in which radiation value > 0
        if (float(l['B_ILAN_212_1']) > 0) and (int(currDate.hour) < startHour):
            startHour = int(currDate.hour)
        #update the latest hour in which radiation value > 0
        if (float(l['B_ILAN_212_1']) > 0) and (int(currDate.hour) > endHour):
            endHour = int(currDate.hour)
    
    #handle the last month
    handle_day_end(prevDate)
    handle_month_end()
# Out:
# New date: 09/01/2021, #elements 14
# New date: 09/02/2021, #elements 14
# New date: 09/03/2021, #elements 14
# New date: 09/04/2021, #elements 14
# New date: 09/05/2021, #elements 14
# New date: 09/06/2021, #elements 14
# New date: 09/07/2021, #elements 14
# New date: 09/08/2021, #elements 14
# New date: 09/09/2021, #elements 14
# New date: 09/10/2021, #elements 14
# New date: 09/11/2021, #elements 14
# New date: 09/12/2021, #elements 14
# New date: 09/13/2021, #elements 14
# New date: 09/14/2021, #elements 14
# New date: 09/15/2021, #elements 14
# New date: 09/16/2021, #elements 14
# New date: 09/17/2021, #elements 14
# New date: 09/18/2021, #elements 14
# New date: 09/19/2021, #elements 14
# New date: 09/20/2021, #elements 14
# New date: 09/21/2021, #elements 14
# New date: 09/22/2021, #elements 14
# New date: 09/23/2021, #elements 14
# New date: 09/24/2021, #elements 14
# New date: 09/25/2021, #elements 14
# New date: 09/26/2021, #elements 14
# New date: 09/27/2021, #elements 14
# New date: 09/28/2021, #elements 14
# New date: 09/29/2021, #elements 14
# New date: 09/30/2021, #elements 14
# New month: 10, saving to file bar_ilan-09-21.csv, start: 6, end 18
# New date: 10/01/2021, #elements 14
# New date: 10/02/2021, #elements 14
# New date: 10/03/2021, #elements 14
# New date: 10/04/2021, #elements 14
# New date: 10/05/2021, #elements 14
# New date: 10/06/2021, #elements 14
# New date: 10/07/2021, #elements 14
# New date: 10/08/2021, #elements 14
# New date: 10/09/2021, #elements 14
# New date: 10/10/2021, #elements 14
# New date: 10/11/2021, #elements 14
# New date: 10/12/2021, #elements 14
# New date: 10/13/2021, #elements 14
# New date: 10/14/2021, #elements 14
# New date: 10/15/2021, #elements 14
# New date: 10/16/2021, #elements 14
# New date: 10/17/2021, #elements 14
# New date: 10/18/2021, #elements 14
# New date: 10/19/2021, #elements 14
# New date: 10/20/2021, #elements 14
# New date: 10/21/2021, #elements 14
# New date: 10/22/2021, #elements 14
# New date: 10/23/2021, #elements 14
# New date: 10/24/2021, #elements 14
# New date: 10/25/2021, #elements 14
# New date: 10/26/2021, #elements 14
# New date: 10/27/2021, #elements 14
# New date: 10/28/2021, #elements 14
# New date: 10/29/2021, #elements 14
# New date: 10/30/2021, #elements 14
# New date: 10/31/2021, #elements 14
# New month: 11, saving to file bar_ilan-10-21.csv, start: 6, end 18
# New date: 11/01/2021, #elements 14
# New date: 11/02/2021, #elements 14
# New date: 11/03/2021, #elements 14
# New date: 11/04/2021, #elements 14
# New date: 11/05/2021, #elements 14
# New date: 11/06/2021, #elements 14
# New date: 11/07/2021, #elements 14
# New date: 11/08/2021, #elements 14
# New date: 11/09/2021, #elements 14
# New date: 11/10/2021, #elements 14
# New date: 11/11/2021, #elements 14
# New date: 11/12/2021, #elements 14
# New date: 11/13/2021, #elements 14
# New date: 11/14/2021, #elements 14
# New date: 11/15/2021, #elements 14
# New date: 11/16/2021, #elements 14
# New date: 11/17/2021, #elements 14
# New date: 11/18/2021, #elements 14
# New date: 11/19/2021, #elements 14
# New date: 11/20/2021, #elements 14
# New date: 11/21/2021, #elements 14
# New date: 11/22/2021, #elements 14
# New date: 11/23/2021, #elements 14
# New date: 11/24/2021, #elements 14
# New date: 11/25/2021, #elements 14
# New date: 11/26/2021, #elements 14
# New date: 11/27/2021, #elements 14
# New date: 11/28/2021, #elements 14
# New date: 11/29/2021, #elements 14
# New date: 11/30/2021, #elements 14
# New month: 12, saving to file bar_ilan-11-21.csv, start: 6, end 17
# New date: 12/01/2021, #elements 14
# New date: 12/02/2021, #elements 14
# New date: 12/03/2021, #elements 14
# New date: 12/04/2021, #elements 14
# New date: 12/05/2021, #elements 14
# New date: 12/06/2021, #elements 14
# New date: 12/07/2021, #elements 14
# New date: 12/08/2021, #elements 14
# New date: 12/09/2021, #elements 14
# New date: 12/10/2021, #elements 14
# New date: 12/11/2021, #elements 14
# New date: 12/12/2021, #elements 14
# New date: 12/13/2021, #elements 14
# New date: 12/14/2021, #elements 14
# New date: 12/15/2021, #elements 14
# New date: 12/16/2021, #elements 14
# New date: 12/17/2021, #elements 14
# New date: 12/18/2021, #elements 14
# New date: 12/19/2021, #elements 14
# New date: 12/20/2021, #elements 14
# New date: 12/21/2021, #elements 14
# New date: 12/22/2021, #elements 14
# New date: 12/23/2021, #elements 14
# New date: 12/24/2021, #elements 14
# New date: 12/25/2021, #elements 14
# New date: 12/26/2021, #elements 14
# New date: 12/27/2021, #elements 14
# New date: 12/28/2021, #elements 14
# New date: 12/29/2021, #elements 14
# New date: 12/30/2021, #elements 14
# New date: 12/31/2021, #elements 14
# New month: 01, saving to file bar_ilan-12-21.csv, start: 6, end 19
# New date: 01/01/2022, #elements 14
# New date: 01/02/2022, #elements 14
# New date: 01/03/2022, #elements 14
# New date: 01/04/2022, #elements 14
# New date: 01/05/2022, #elements 14
# New date: 01/06/2022, #elements 14
# New date: 01/07/2022, #elements 14
# New date: 01/08/2022, #elements 14
# New date: 01/09/2022, #elements 14
# New date: 01/10/2022, #elements 14
# New date: 01/11/2022, #elements 14
# New date: 01/12/2022, #elements 14
# New date: 01/13/2022, #elements 14
# New date: 01/14/2022, #elements 14
# New date: 01/15/2022, #elements 14
# New date: 01/16/2022, #elements 14
# New date: 01/17/2022, #elements 14
# New date: 01/18/2022, #elements 14
# New date: 01/19/2022, #elements 14
# New date: 01/20/2022, #elements 14
# New date: 01/21/2022, #elements 14
# New date: 01/22/2022, #elements 14
# New date: 01/23/2022, #elements 14
# New date: 01/24/2022, #elements 14
# New date: 01/25/2022, #elements 14
# New date: 01/26/2022, #elements 14
# New date: 01/27/2022, #elements 14
# New date: 01/28/2022, #elements 14
# New date: 01/29/2022, #elements 14
# New date: 01/30/2022, #elements 14
# New date: 01/31/2022, #elements 14
# New month: 02, saving to file bar_ilan-01-22.csv, start: 6, end 19
# New date: 02/01/2022, #elements 14
# New date: 02/02/2022, #elements 14
# New date: 02/03/2022, #elements 14
# New date: 02/04/2022, #elements 14
# New date: 02/05/2022, #elements 14
# New date: 02/06/2022, #elements 14
# New date: 02/07/2022, #elements 14
# New date: 02/08/2022, #elements 14
# New date: 02/09/2022, #elements 14
# New date: 02/10/2022, #elements 14
# New date: 02/11/2022, #elements 14
# New date: 02/12/2022, #elements 14
# New date: 02/13/2022, #elements 14
# New date: 02/14/2022, #elements 14
# New date: 02/15/2022, #elements 14
# New date: 02/16/2022, #elements 14
# New date: 02/17/2022, #elements 14
# New date: 02/18/2022, #elements 14
# New date: 02/19/2022, #elements 14
# New date: 02/20/2022, #elements 14
# New date: 02/21/2022, #elements 14
# New date: 02/22/2022, #elements 14
# New date: 02/23/2022, #elements 14
# New date: 02/24/2022, #elements 14
# New date: 02/25/2022, #elements 14
# New date: 02/26/2022, #elements 14
# New date: 02/27/2022, #elements 14
# New date: 02/28/2022, #elements 14
# New month: 03, saving to file bar_ilan-02-22.csv, start: 7, end 18
# New date: 03/01/2022, #elements 14
# New date: 03/02/2022, #elements 14
# New date: 03/03/2022, #elements 14
# New date: 03/04/2022, #elements 14
# New date: 03/05/2022, #elements 14
# New date: 03/06/2022, #elements 14
# New date: 03/07/2022, #elements 14
# New date: 03/08/2022, #elements 14
# New date: 03/09/2022, #elements 14
# New date: 03/10/2022, #elements 14
# New date: 03/11/2022, #elements 14
# New date: 03/12/2022, #elements 14
# New date: 03/13/2022, #elements 14
# New date: 03/14/2022, #elements 14
# New date: 03/15/2022, #elements 14
# New date: 03/16/2022, #elements 14
# New date: 03/17/2022, #elements 14
# New date: 03/18/2022, #elements 14
# New date: 03/19/2022, #elements 14
# New date: 03/20/2022, #elements 14
# New date: 03/21/2022, #elements 14
# New date: 03/22/2022, #elements 14
# New date: 03/23/2022, #elements 14
# New date: 03/24/2022, #elements 14
# New date: 03/25/2022, #elements 14
# New date: 03/26/2022, #elements 14
# New date: 03/27/2022, #elements 14
# New date: 03/28/2022, #elements 14
# New date: 03/29/2022, #elements 14
# New date: 03/30/2022, #elements 14
# New date: 03/31/2022, #elements 14
# New month: 04, saving to file bar_ilan-03-22.csv, start: 6, end 18
# New date: 04/01/2022, #elements 14
# New date: 04/02/2022, #elements 14
# New date: 04/03/2022, #elements 14
# New date: 04/04/2022, #elements 14
# New date: 04/05/2022, #elements 14
# New date: 04/06/2022, #elements 14
# New date: 04/07/2022, #elements 14
# New date: 04/08/2022, #elements 14
# New date: 04/09/2022, #elements 14
# New date: 04/10/2022, #elements 14
# New date: 04/11/2022, #elements 14
# New date: 04/12/2022, #elements 14
# New date: 04/13/2022, #elements 14
# New date: 04/14/2022, #elements 14
# New date: 04/15/2022, #elements 14
# New date: 04/16/2022, #elements 14
# New date: 04/17/2022, #elements 7
# New date: 04/18/2022, #elements 14
# New date: 04/19/2022, #elements 14
# New date: 04/20/2022, #elements 14
# New date: 04/21/2022, #elements 14
# New date: 04/22/2022, #elements 14
# New date: 04/23/2022, #elements 14
# New date: 04/24/2022, #elements 14
# New date: 04/25/2022, #elements 14
# New date: 04/26/2022, #elements 14
# New date: 04/27/2022, #elements 14
# New date: 04/28/2022, #elements 14
# New date: 04/29/2022, #elements 14
# New date: 04/30/2022, #elements 14
# New month: 04, saving to file bar_ilan-04-22.csv, start: 6, end 19
